# %% [markdown]
# # Gait
# ![image.png](attachment:image.png)
# [Alt Text](https://en.wikipedia.org/wiki/Gait#/media/File:Elephant_walking.gif)

# %% [markdown]
# ![image.png](attachment:image.png)
# https://www.sciencedirect.com/science/article/pii/S1002007109002871
